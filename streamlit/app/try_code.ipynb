# %%
file_path = "test_results.txt"

try:
    with open(file_path, "r") as file:
        # Read the entire content of the file
        content = file.read()

    # Do something with the content
    print(content)
except FileNotFoundError:
    print(f"File not found: {file_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.8.12, pytest-7.1.3, pluggy-1.0.0
# rootdir: /home/jerome/code/J-Pouzoulet/IA3/pytest_exo/streamlit/app
# plugins: anyio-3.6.2, asyncio-0.19.0
# asyncio: mode=strict
# collected 14 items
#
# test_tests.py FFFFFFFFFFFFFF                                             [100%]
#
# =================================== FAILURES ===================================
# ______________________________ test_solution[0-] _______________________________
#
# input_val = 0, expected_output = ''
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == ''
# E        +  where None = <exercice.Solution object at 0x7fc11871a5e0>.output
# E        +    where <exercice.Solution object at 0x7fc11871a5e0> = Solution(0)
#
# test_tests.py:21: AssertionError
# ______________________________ test_solution[1-I] ______________________________
#
# input_val = 1, expected_output = 'I'
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == 'I'
# E        +  where None = <exercice.Solution object at 0x7fc11871ad00>.output
# E        +    where <exercice.Solution object at 0x7fc11871ad00> = Solution(1)
#
# test_tests.py:21: AssertionError
# _____________________________ test_solution[2-II] ______________________________
#
# input_val = 2, expected_output = 'II'
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == 'II'
# E        +  where None = <exercice.Solution object at 0x7fc1186c7910>.output
# E        +    where <exercice.Solution object at 0x7fc1186c7910> = Solution(2)
#
# test_tests.py:21: AssertionError
# _____________________________ test_solution[4-IV] ______________________________
#
# input_val = 4, expected_output = 'IV'
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == 'IV'
# E        +  where None = <exercice.Solution object at 0x7fc1186c7f40>.output
# E        +    where <exercice.Solution object at 0x7fc1186c7f40> = Solution(4)
#
# test_tests.py:21: AssertionError
# ____________________________ test_solution[44-XLIV] ____________________________
#
# input_val = 44, expected_output = 'XLIV'
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == 'XLIV'
# E        +  where None = <exercice.Solution object at 0x7fc1186c7d30>.output
# E        +    where <exercice.Solution object at 0x7fc1186c7d30> = Solution(44)
#
# test_tests.py:21: AssertionError
# ____________________________ test_solution[66-LXVI] ____________________________
#
# input_val = 66, expected_output = 'LXVI'
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == 'LXVI'
# E        +  where None = <exercice.Solution object at 0x7fc118673790>.output
# E        +    where <exercice.Solution object at 0x7fc118673790> = Solution(66)
#
# test_tests.py:21: AssertionError
# ___________________________ test_solution[89-LXXXIX] ___________________________
#
# input_val = 89, expected_output = 'LXXXIX'
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == 'LXXXIX'
# E        +  where None = <exercice.Solution object at 0x7fc118678220>.output
# E        +    where <exercice.Solution object at 0x7fc118678220> = Solution(89)
#
# test_tests.py:21: AssertionError
# ____________________________ test_solution[99-XCIX] ____________________________
#
# input_val = 99, expected_output = 'XCIX'
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == 'XCIX'
# E        +  where None = <exercice.Solution object at 0x7fc11871a5b0>.output
# E        +    where <exercice.Solution object at 0x7fc11871a5b0> = Solution(99)
#
# test_tests.py:21: AssertionError
# ___________________________ test_solution[149-CXLIX] ___________________________
#
# input_val = 149, expected_output = 'CXLIX'
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == 'CXLIX'
# E        +  where None = <exercice.Solution object at 0x7fc118673490>.output
# E        +    where <exercice.Solution object at 0x7fc118673490> = Solution(149)
#
# test_tests.py:21: AssertionError
# __________________________ test_solution[271-CCLXXI] ___________________________
#
# input_val = 271, expected_output = 'CCLXXI'
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == 'CCLXXI'
# E        +  where None = <exercice.Solution object at 0x7fc1186c71c0>.output
# E        +    where <exercice.Solution object at 0x7fc1186c71c0> = Solution(271)
#
# test_tests.py:21: AssertionError
# __________________________ test_solution[1026-MXXVI] ___________________________
#
# input_val = 1026, expected_output = 'MXXVI'
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == 'MXXVI'
# E        +  where None = <exercice.Solution object at 0x7fc118673220>.output
# E        +    where <exercice.Solution object at 0x7fc118673220> = Solution(1026)
#
# test_tests.py:21: AssertionError
# _________________________ test_solution[2999-MMCMXCIX] _________________________
#
# input_val = 2999, expected_output = 'MMCMXCIX'
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == 'MMCMXCIX'
# E        +  where None = <exercice.Solution object at 0x7fc118678400>.output
# E        +    where <exercice.Solution object at 0x7fc118678400> = Solution(2999)
#
# test_tests.py:21: AssertionError
# ________________________ test_solution[3725-MMMDCCXXV] _________________________
#
# input_val = 3725, expected_output = 'MMMDCCXXV'
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == 'MMMDCCXXV'
# E        +  where None = <exercice.Solution object at 0x7fc118681250>.output
# E        +    where <exercice.Solution object at 0x7fc118681250> = Solution(3725)
#
# test_tests.py:21: AssertionError
# ________________________ test_solution[4999-MMMMCMXCIX] ________________________
#
# input_val = 4999, expected_output = 'MMMMCMXCIX'
#
#     @pytest.mark.parametrize("input_val, expected_output", test_cases.items())
#     def test_solution(input_val, expected_output):
# >       assert Solution(input_val).output == expected_output
# E       AssertionError: assert None == 'MMMMCMXCIX'
# E        +  where None = <exercice.Solution object at 0x7fc118681f40>.output
# E        +    where <exercice.Solution object at 0x7fc118681f40> = Solution(4999)
#
# test_tests.py:21: AssertionError
# =========================== short test summary info ============================
# FAILED test_tests.py::test_solution[0-] - AssertionError: assert None == ''
# FAILED test_tests.py::test_solution[1-I] - AssertionError: assert None == 'I'
# FAILED test_tests.py::test_solution[2-II] - AssertionError: assert None == 'II'
# FAILED test_tests.py::test_solution[4-IV] - AssertionError: assert None == 'IV'
# FAILED test_tests.py::test_solution[44-XLIV] - AssertionError: assert None ==...
# FAILED test_tests.py::test_solution[66-LXVI] - AssertionError: assert None ==...
# FAILED test_tests.py::test_solution[89-LXXXIX] - AssertionError: assert None ...
# FAILED test_tests.py::test_solution[99-XCIX] - AssertionError: assert None ==...
# FAILED test_tests.py::test_solution[149-CXLIX] - AssertionError: assert None ...
# FAILED test_tests.py::test_solution[271-CCLXXI] - AssertionError: assert None...
# FAILED test_tests.py::test_solution[1026-MXXVI] - AssertionError: assert None...
# FAILED test_tests.py::test_solution[2999-MMCMXCIX] - AssertionError: assert N...
# FAILED test_tests.py::test_solution[3725-MMMDCCXXV] - AssertionError: assert ...
# FAILED test_tests.py::test_solution[4999-MMMMCMXCIX] - AssertionError: assert...
# ============================== 14 failed in 0.05s ==============================

# %%
type(content)
# Out:
# str
